# %%
from TCIAClient import TCIAClient
import pandas as pd

# %%
base_url = 'https://nbia.cancerimagingarchive.net/nbia-api/services/v4/'
client = TCIAClient(base_url)

# %%
collection_df = pd.DataFrame(data=client.get_json('getCollectionValues'))
collection_df.head()
# Out:
#                       Collection
# 0                        4D-Lung
# 1                        A091105
# 2                       ACNS0332
# 3                     ACRIN-6698
# 4  ACRIN-Contralateral-Breast-MR

# %%
series_df = pd.DataFrame(data=client.get_json('getSeries', {'Collection': 'Lung-PET-CT-Dx'}))
series_df.head()
# Out:
#                                    SeriesInstanceUID  \
# 0  1.3.6.1.4.1.14519.5.2.1.6655.2359.115443980116...
# 1  1.3.6.1.4.1.14519.5.2.1.6655.2359.142073665012...
# 2  1.3.6.1.4.1.14519.5.2.1.6655.2359.192913516459...
# 3  1.3.6.1.4.1.14519.5.2.1.6655.2359.650617506468...
# 4  1.3.6.1.4.1.14519.5.2.1.6655.2359.204257665465...
#
#                                     StudyInstanceUID Modality ProtocolName  \
# 0  1.3.6.1.4.1.14519.5.2.1.6655.2359.165244450683...       CT     5.84 POS
# 1  1.3.6.1.4.1.14519.5.2.1.6655.2359.165244450683...       CT     5.84 POS
# 2  1.3.6.1.4.1.14519.5.2.1.6655.2359.165244450683...       CT     5.84 POS
# 3  1.3.6.1.4.1.14519.5.2.1.6655.2359.165244450683...       CT     5.84 POS
# 4  1.3.6.1.4.1.14519.5.2.1.6655.2359.171494204612...       CT     5.84 POS
#
#    SeriesDate SeriesDescription  SeriesNumber      Collection Site  \
# 0  08-22-2008      Recon 2: 5mm             5  Lung-PET-CT-Dx  HIT
# 1  08-22-2008               5mm             2  Lung-PET-CT-Dx  HIT
# 2  08-22-2008               5mm             4  Lung-PET-CT-Dx  HIT
# 3  08-22-2008      Recon 2: 5mm             3  Lung-PET-CT-Dx  HIT
# 4  02-13-2009               5mm             3  Lung-PET-CT-Dx  HIT
#
#        PatientID  ...                                    LicenseURI  \
# 0  Lung_Dx-A0012  ...  https://creativecommons.org/licenses/by/4.0/
# 1  Lung_Dx-A0012  ...  https://creativecommons.org/licenses/by/4.0/
# 2  Lung_Dx-A0012  ...  https://creativecommons.org/licenses/by/4.0/
# 3  Lung_Dx-A0012  ...  https://creativecommons.org/licenses/by/4.0/
# 4  Lung_Dx-A0013  ...  https://creativecommons.org/licenses/by/4.0/
#
#                             DataDescriptionURI  FileSize ReleasedStatus  \
# 0  https://doi.org/10.7937/TCIA.2020.NNC2-0461  18493580            Yes
# 1  https://doi.org/10.7937/TCIA.2020.NNC2-0461  19021680            Yes
# 2  https://doi.org/10.7937/TCIA.2020.NNC2-0461  18493370            Yes
# 3  https://doi.org/10.7937/TCIA.2020.NNC2-0461  19021896            Yes
# 4  https://doi.org/10.7937/TCIA.2020.NNC2-0461   4226992            Yes
#
#   DateReleased  StudyDesc   StudyDate Authorized BodyPartExamined  \
# 0   06-17-2020      Chest  08-22-2008          1              NaN
# 1   06-17-2020      Chest  08-22-2008          1              NaN
# 2   06-17-2020      Chest  08-22-2008          1              NaN
# 3   06-17-2020      Chest  08-22-2008          1              NaN
# 4   06-17-2020        POS  02-13-2009          1              NaN
#
#   ThirdPartyAnalysis
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 28 columns]

# %%
patient_df = pd.DataFrame(data=client.get_json('getPatientStudy', {'Collection': 'Lung-PET-CT-Dx'}))
patient_df.head()
# Out:
#                                     StudyInstanceUID   StudyDate  \
# 0  1.3.6.1.4.1.14519.5.2.1.6655.2359.165554066086...  04-04-2007
# 1  1.3.6.1.4.1.14519.5.2.1.6655.2359.104855313699...  04-25-2007
# 2  1.3.6.1.4.1.14519.5.2.1.6655.2359.179476503242...  07-07-2006
# 3  1.3.6.1.4.1.14519.5.2.1.6655.2359.191296879859...  07-25-2006
# 4  1.3.6.1.4.1.14519.5.2.1.6655.2359.197033995568...  07-21-2006
#
#                 StudyDescription PatientAge      PatientID    PatientName  \
# 0                          Chest       058Y  Lung_Dx-A0001  Lung_Dx-A0001
# 1  Thorax^AThoraxRoutine (Adult)       053Y  Lung_Dx-A0002  Lung_Dx-A0002
# 2  Thorax^AThoraxRoutine (Adult)       060Y  Lung_Dx-A0003  Lung_Dx-A0003
# 3                          Chest       060Y  Lung_Dx-A0003  Lung_Dx-A0003
# 4                          Chest       060Y  Lung_Dx-A0003  Lung_Dx-A0003
#
#   PatientSex      Collection  SeriesCount  Authorized
# 0          M  Lung-PET-CT-Dx            2           1
# 1          F  Lung-PET-CT-Dx            2           1
# 2          M  Lung-PET-CT-Dx            2           1
# 3          M  Lung-PET-CT-Dx            2           1
# 4          M  Lung-PET-CT-Dx            2           1

# %%
test_uid = series_df.iloc[0]['SeriesInstanceUID']

# %%
client.get_image(test_uid, './test/test.zip', True, True)
# Out:
# True
